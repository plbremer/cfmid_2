# %%
import pandas as pd
import numpy as np

# %%
file_address='../../../results/[M+H]+/hcd/precursor_no/similarity_subset_nist20_only_hcd_only_[M+H]+_no_metlin.txt'
output_address='../../../results/compound_exploration/[M+H]+_hcd_relevant_inchikeys.bin'

# %%
temp=pd.read_csv(file_address,sep='¬')
# Out:
# <ipython-input-3-06e789cdf4f3>:1: ParserWarning: Falling back to the 'python' engine because the separator encoded in utf-8 is > 1 char long, and the 'c' engine does not support such separators; you can avoid this warning by specifying engine='python'.
#   temp=pd.read_csv(file_address,sep='¬')

# %%
temp[0:5]
# Out:
#        CASNO Collision_energy Collision_gas  \
# 0  110044821       NCE=5% 3eV            N2
# 1  110044821       NCE=5% 3eV            N2
# 2  110044821       NCE=5% 3eV            N2
# 3  110044821      NCE=10% 6eV            N2
# 4  110044821      NCE=10% 6eV            N2
#
#                               Comment   ExactMass     Formula     ID  \
# 0  NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43130
# 1  NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43130
# 2  NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43130
# 3  NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43131
# 4  NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43131
#
#    In-source_voltage                     InChIKey  \
# 0                NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
# 1                NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
# 2                NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
# 3                NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
# 4                NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
#
#                        Instrument  ... PrecursorMZ Precursor_type  \
# 0  Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
# 1  Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
# 2  Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
# 3  Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
# 4  Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
#
#   Related_CAS#           Sample_inlet  Spectrum_type                   Synon  \
# 0          NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
# 1          NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
# 2          NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
# 3          NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
# 4          NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
#
#   msN_pathway  energy#                     Superclass  dot_product
# 0         NaN  energy0  Organic acids and derivatives     0.862267
# 1         NaN  energy1  Organic acids and derivatives     0.877183
# 2         NaN  energy2  Organic acids and derivatives     0.957392
# 3         NaN  energy0  Organic acids and derivatives     0.842509
# 4         NaN  energy1  Organic acids and derivatives     0.860210
#
# [5 rows x 29 columns]

# %%
temp=temp.loc[temp['energy#']=='energy2',temp.columns]

# %%
temp[0:5]
# Out:
#         CASNO Collision_energy Collision_gas  \
# 2   110044821       NCE=5% 3eV            N2
# 5   110044821      NCE=10% 6eV            N2
# 8   110044821     NCE=15% 10eV            N2
# 11  110044821     NCE=20% 15eV            N2
# 14  110044821     NCE=30% 23eV            N2
#
#                                Comment   ExactMass     Formula     ID  \
# 2   NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43130
# 5   NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43131
# 8   NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43132
# 11  NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43133
# 14  NIST Mass Spectrometry Data Center  383.278406  C20H37N3O4  43134
#
#     In-source_voltage                     InChIKey  \
# 2                 NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
# 5                 NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
# 8                 NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
# 11                NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
# 14                NaN  FMYKJLXRRQTBOR-SQNIBIBYSA-N
#
#                         Instrument  ... PrecursorMZ Precursor_type  \
# 2   Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
# 5   Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
# 8   Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
# 11  Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
# 14  Thermo Finnigan Elite Orbitrap  ...    384.2857         [M+H]+
#
#    Related_CAS#           Sample_inlet  Spectrum_type                   Synon  \
# 2           NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
# 5           NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
# 8           NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
# 11          NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
# 14          NaN  direct flow injection            MS2  Ac-Leu-Leu-Norleucinal
#
#    msN_pathway  energy#                     Superclass  dot_product
# 2          NaN  energy2  Organic acids and derivatives     0.957392
# 5          NaN  energy2  Organic acids and derivatives     0.953854
# 8          NaN  energy2  Organic acids and derivatives     0.881049
# 11         NaN  energy2  Organic acids and derivatives     0.802880
# 14         NaN  energy2  Organic acids and derivatives     0.785905
#
# [5 rows x 29 columns]

# %%
temp.columns
# Out:
# Index(['CASNO', 'Collision_energy', 'Collision_gas', 'Comment', 'ExactMass',
#        'Formula', 'ID', 'In-source_voltage', 'InChIKey', 'Instrument',
#        'Instrument_type', 'Ion_mode', 'Ionization', 'Link', 'MW', 'NISTNO',
#        'Name', 'Notes', 'Num peaks', 'PrecursorMZ', 'Precursor_type',
#        'Related_CAS#', 'Sample_inlet', 'Spectrum_type', 'Synon', 'msN_pathway',
#        'energy#', 'Superclass', 'dot_product'],
#       dtype='object')

# %%
temp=temp.loc[:,['Collision_energy','InChIKey','Instrument_type', 'Ion_mode', 'Ionization','NISTNO',
       'PrecursorMZ', 'Precursor_type',
       'Spectrum_type','energy#', 'Superclass', 'dot_product']]

# %%
temp
# Out:
#        Collision_energy                     InChIKey Instrument_type Ion_mode  \
# 2            NCE=5% 3eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 5           NCE=10% 6eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 8          NCE=15% 10eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 11         NCE=20% 15eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 14         NCE=30% 23eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# ...                 ...                          ...             ...      ...
# 472208     NCE=35% 61eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
# 472211     NCE=44% 75eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
# 472214     NCE=54% 91eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
# 472217    NCE=65% 109eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
# 472220    NCE=76% 126eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
#
#        Ionization   NISTNO  PrecursorMZ Precursor_type Spectrum_type  energy#  \
# 2             ESI  1128176     384.2857         [M+H]+           MS2  energy2
# 5             ESI  1128177     384.2857         [M+H]+           MS2  energy2
# 8             ESI  1128178     384.2857         [M+H]+           MS2  energy2
# 11            ESI  1128179     384.2857         [M+H]+           MS2  energy2
# 14            ESI  1128180     384.2857         [M+H]+           MS2  energy2
# ...           ...      ...          ...            ...           ...      ...
# 472208        ESI  3484975     864.6229         [M+H]+           MS2  energy2
# 472211        ESI  3484976     864.6229         [M+H]+           MS2  energy2
# 472214        ESI  3484977     864.6229         [M+H]+           MS2  energy2
# 472217        ESI  3484978     864.6229         [M+H]+           MS2  energy2
# 472220        ESI  3484979     864.6229         [M+H]+           MS2  energy2
#
#                              Superclass  dot_product
# 2         Organic acids and derivatives     0.957392
# 5         Organic acids and derivatives     0.953854
# 8         Organic acids and derivatives     0.881049
# 11        Organic acids and derivatives     0.802880
# 14        Organic acids and derivatives     0.785905
# ...                                 ...          ...
# 472208  Lipids and lipid-like molecules     0.993067
# 472211  Lipids and lipid-like molecules     0.995980
# 472214  Lipids and lipid-like molecules     0.998376
# 472217  Lipids and lipid-like molecules     0.999250
# 472220  Lipids and lipid-like molecules     1.000000
#
# [157407 rows x 12 columns]

# %%
temp=temp.loc[temp['Collision_energy'].str.contains('eV'),temp.columns]        
temp['experimental_collision_parsed']=temp['Collision_energy'].str.findall(r'[0-9]+').str[1].astype(float)

# %%
temp
# Out:
#        Collision_energy                     InChIKey Instrument_type Ion_mode  \
# 2            NCE=5% 3eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 5           NCE=10% 6eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 8          NCE=15% 10eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 11         NCE=20% 15eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 14         NCE=30% 23eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# ...                 ...                          ...             ...      ...
# 472208     NCE=35% 61eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
# 472211     NCE=44% 75eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
# 472214     NCE=54% 91eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
# 472217    NCE=65% 109eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
# 472220    NCE=76% 126eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
#
#        Ionization   NISTNO  PrecursorMZ Precursor_type Spectrum_type  energy#  \
# 2             ESI  1128176     384.2857         [M+H]+           MS2  energy2
# 5             ESI  1128177     384.2857         [M+H]+           MS2  energy2
# 8             ESI  1128178     384.2857         [M+H]+           MS2  energy2
# 11            ESI  1128179     384.2857         [M+H]+           MS2  energy2
# 14            ESI  1128180     384.2857         [M+H]+           MS2  energy2
# ...           ...      ...          ...            ...           ...      ...
# 472208        ESI  3484975     864.6229         [M+H]+           MS2  energy2
# 472211        ESI  3484976     864.6229         [M+H]+           MS2  energy2
# 472214        ESI  3484977     864.6229         [M+H]+           MS2  energy2
# 472217        ESI  3484978     864.6229         [M+H]+           MS2  energy2
# 472220        ESI  3484979     864.6229         [M+H]+           MS2  energy2
#
#                              Superclass  dot_product  \
# 2         Organic acids and derivatives     0.957392
# 5         Organic acids and derivatives     0.953854
# 8         Organic acids and derivatives     0.881049
# 11        Organic acids and derivatives     0.802880
# 14        Organic acids and derivatives     0.785905
# ...                                 ...          ...
# 472208  Lipids and lipid-like molecules     0.993067
# 472211  Lipids and lipid-like molecules     0.995980
# 472214  Lipids and lipid-like molecules     0.998376
# 472217  Lipids and lipid-like molecules     0.999250
# 472220  Lipids and lipid-like molecules     1.000000
#
#         experimental_collision_parsed
# 2                                 3.0
# 5                                 6.0
# 8                                10.0
# 11                               15.0
# 14                               23.0
# ...                               ...
# 472208                           61.0
# 472211                           75.0
# 472214                           91.0
# 472217                          109.0
# 472220                          126.0
#
# [109771 rows x 13 columns]

# %%
temp.experimental_collision_parsed.value_counts()
# Out:
# 15.0     2792
# 14.0     2749
# 18.0     2654
# 11.0     2647
# 19.0     2647
#          ...
# 196.0       1
# 237.0       1
# 206.0       1
# 205.0       1
# 242.0       1
# Name: experimental_collision_parsed, Length: 230, dtype: int64

# %%
temp.dot_product.hist()
# Out:
# <AxesSubplot:>

# %%
temp.loc[temp.experimental_collision_parsed==40].InChIKey.value_counts()
# Out:
# AIFXMSDWXBFQTF-SNXGECCISA-N    1
# HUPGTAGQEXENPN-QIUKOVNNSA-N    1
# NPDQZDCDWUBCQK-UHFFFAOYSA-N    1
# XFZNIUMLNKPJGO-UHFFFAOYSA-N    1
# RDRQUUWCJTYHCT-UHFFFAOYSA-N    1
#                               ..
# ABZAYLFRWGIRDU-UHFFFAOYSA-N    1
# MZSVPTRXUHRPHP-UHFFFAOYSA-N    1
# MXBSTXKKPYUUAP-UHFFFAOYSA-N    1
# IADWMRZHOGHTMQ-UHFFFAOYSA-N    1
# CBPCFMMAXNCEHC-UHFFFAOYSA-N    1
# Name: InChIKey, Length: 1159, dtype: int64

# %%
temp.loc[(temp.experimental_collision_parsed>35) & (temp.experimental_collision_parsed<45)]
# Out:
#        Collision_energy                     InChIKey Instrument_type Ion_mode  \
# 20         NCE=50% 38eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 59         NCE=30% 41eV  FAXGPCHRFPCXOO-DPQSSDLTSA-N             HCD        P
# 62         NCE=30% 43eV  FAXGPCHRFPCXOO-DPQSSDLTSA-N             HCD        P
# 98         NCE=30% 37eV  MQKSCOKUMZMISB-GPWKTZPCSA-N             HCD        P
# 101        NCE=30% 39eV  MQKSCOKUMZMISB-GPWKTZPCSA-N             HCD        P
# ...                 ...                          ...             ...      ...
# 435464     NCE=35% 42eV  INOIOAWTVPHTCJ-GHVJWSGMSA-N             HCD        P
# 435503     NCE=35% 37eV  HQFSCLFJTFOOGZ-GHVJWSGMSA-N             HCD        P
# 435572     NCE=27% 39eV  YFLCMJHFLLCCHN-NVQSTNCTSA-N             HCD        P
# 472166     NCE=20% 42eV  PKLSFJOTJYLMTM-CGAFSULGSA-N             HCD        P
# 472202     NCE=20% 37eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
#
#        Ionization   NISTNO  PrecursorMZ Precursor_type Spectrum_type  energy#  \
# 20            ESI  1128182     384.2857         [M+H]+           MS2  energy2
# 59            ESI  1128496     686.4699         [M+H]+           MS2  energy2
# 62            ESI  1128497     686.4699         [M+H]+           MS2  energy2
# 98            ESI  1129287     624.3954         [M+H]+           MS2  energy2
# 101           ESI  1129288     624.3954         [M+H]+           MS2  energy2
# ...           ...      ...          ...            ...           ...      ...
# 435464        ESI  3431482     574.0254         [M+H]+           MS2  energy2
# 435503        ESI  3431568     476.0581         [M+H]+           MS2  energy2
# 435572        ESI  3431852     675.0520         [M+H]+           MS2  energy2
# 472166        ESI  3484505     991.6676         [M+H]+           MS2  energy2
# 472202        ESI  3484973     864.6229         [M+H]+           MS2  energy2
#
#                              Superclass  dot_product  \
# 20        Organic acids and derivatives     0.784657
# 59        Organic acids and derivatives     0.702553
# 62        Organic acids and derivatives     0.741494
# 98      Lipids and lipid-like molecules     0.887830
# 101     Lipids and lipid-like molecules     0.890464
# ...                                 ...          ...
# 435464                       Benzenoids     0.999495
# 435503                       Benzenoids     0.955231
# 435572                       Benzenoids     0.891397
# 472166  Lipids and lipid-like molecules     0.989249
# 472202  Lipids and lipid-like molecules     0.988349
#
#         experimental_collision_parsed
# 20                               38.0
# 59                               41.0
# 62                               43.0
# 98                               37.0
# 101                              39.0
# ...                               ...
# 435464                           42.0
# 435503                           37.0
# 435572                           39.0
# 472166                           42.0
# 472202                           37.0
#
# [10220 rows x 13 columns]

# %%
temp.loc[(temp.experimental_collision_parsed>35) & (temp.experimental_collision_parsed<45)].InChIKey.value_counts()
# Out:
# WYZWZEOGROVVHK-RPJJWQTDSA-N    3
# KWJLIVYSOHTHDR-UHFFFAOYSA-N    3
# CLSDNFWKGFJIBZ-SFYZADRCSA-N    3
# YOSJCQJJIHEUKA-UHFFFAOYSA-N    3
# UZEGGYTUIIXOIX-UHFFFAOYSA-N    3
#                               ..
# XPZYHRSDEFWWSL-UHFFFAOYSA-N    1
# BZOZGJQCWOWAFO-UHFFFAOYSA-N    1
# BLQYVHBZHAISJM-CMDGGOBGSA-N    1
# FSHPUEUAQIHNFD-UHFFFAOYSA-N    1
# JGPIWNNFLKDTSR-UHFFFAOYSA-N    1
# Name: InChIKey, Length: 8305, dtype: int64

# %%
temp.InChIKey.value_counts()
# Out:
# UFPWOSSFAUAVAQ-UHFFFAOYSA-N    29
# AMJVXOOGGBPVCZ-UHFFFAOYSA-N    29
# WYZWZEOGROVVHK-RPJJWQTDSA-N    28
# WDICXYMIEJAABR-UHFFFAOYSA-N    28
# XFYLLCQSZNHDLM-UHFFFAOYSA-N    27
#                                ..
# NFPZOORPDJBGME-ZLEUIESPSA-N     1
# FZBGZDZLYSLJFE-MVAMGWTESA-N     1
# XCQNRWMPPLJRCM-PZSVWFBASA-N     1
# KRVDMABBKYMBHG-UHFFFAOYSA-N     1
# CUPGMRSSZADEIW-UHFFFAOYSA-N     1
# Name: InChIKey, Length: 8933, dtype: int64

# %%
temp.loc[(temp.experimental_collision_parsed>35) & (temp.experimental_collision_parsed<45)]
# Out:
#        Collision_energy                     InChIKey Instrument_type Ion_mode  \
# 20         NCE=50% 38eV  FMYKJLXRRQTBOR-SQNIBIBYSA-N             HCD        P
# 59         NCE=30% 41eV  FAXGPCHRFPCXOO-DPQSSDLTSA-N             HCD        P
# 62         NCE=30% 43eV  FAXGPCHRFPCXOO-DPQSSDLTSA-N             HCD        P
# 98         NCE=30% 37eV  MQKSCOKUMZMISB-GPWKTZPCSA-N             HCD        P
# 101        NCE=30% 39eV  MQKSCOKUMZMISB-GPWKTZPCSA-N             HCD        P
# ...                 ...                          ...             ...      ...
# 435464     NCE=35% 42eV  INOIOAWTVPHTCJ-GHVJWSGMSA-N             HCD        P
# 435503     NCE=35% 37eV  HQFSCLFJTFOOGZ-GHVJWSGMSA-N             HCD        P
# 435572     NCE=27% 39eV  YFLCMJHFLLCCHN-NVQSTNCTSA-N             HCD        P
# 472166     NCE=20% 42eV  PKLSFJOTJYLMTM-CGAFSULGSA-N             HCD        P
# 472202     NCE=20% 37eV  UAKYQMHTPLVMJD-GJOJTGTQSA-N             HCD        P
#
#        Ionization   NISTNO  PrecursorMZ Precursor_type Spectrum_type  energy#  \
# 20            ESI  1128182     384.2857         [M+H]+           MS2  energy2
# 59            ESI  1128496     686.4699         [M+H]+           MS2  energy2
# 62            ESI  1128497     686.4699         [M+H]+           MS2  energy2
# 98            ESI  1129287     624.3954         [M+H]+           MS2  energy2
# 101           ESI  1129288     624.3954         [M+H]+           MS2  energy2
# ...           ...      ...          ...            ...           ...      ...
# 435464        ESI  3431482     574.0254         [M+H]+           MS2  energy2
# 435503        ESI  3431568     476.0581         [M+H]+           MS2  energy2
# 435572        ESI  3431852     675.0520         [M+H]+           MS2  energy2
# 472166        ESI  3484505     991.6676         [M+H]+           MS2  energy2
# 472202        ESI  3484973     864.6229         [M+H]+           MS2  energy2
#
#                              Superclass  dot_product  \
# 20        Organic acids and derivatives     0.784657
# 59        Organic acids and derivatives     0.702553
# 62        Organic acids and derivatives     0.741494
# 98      Lipids and lipid-like molecules     0.887830
# 101     Lipids and lipid-like molecules     0.890464
# ...                                 ...          ...
# 435464                       Benzenoids     0.999495
# 435503                       Benzenoids     0.955231
# 435572                       Benzenoids     0.891397
# 472166  Lipids and lipid-like molecules     0.989249
# 472202  Lipids and lipid-like molecules     0.988349
#
#         experimental_collision_parsed
# 20                               38.0
# 59                               41.0
# 62                               43.0
# 98                               37.0
# 101                              39.0
# ...                               ...
# 435464                           42.0
# 435503                           37.0
# 435572                           39.0
# 472166                           42.0
# 472202                           37.0
#
# [10220 rows x 13 columns]

# %%
temp.loc[(temp.experimental_collision_parsed>35) & (temp.experimental_collision_parsed<45)].dot_product.hist()
# Out:
# <AxesSubplot:>

# %%
inchikeys=temp.loc[(temp.experimental_collision_parsed>35) & (temp.experimental_collision_parsed<45)].InChIKey.unique()

# %%
#for each inchikey
#select the row that has the eV closest to 40
#in the event of a tie, chose the smaller number


#core information that we want
##inchikey
##dot product
##parsed experiment energy

# %%
results={
    'inchikey':[],
    'dot_product':[],
    'exp_energy_parsed':[]
}

# %%
#go through all inchikeys
#for each inchikey, select the zone with ev between 35 and 45 (so we dont get anything too far off "optimal")
#select the row with the minimum ev of all of those between 35 and 45
#could maybe select the one closest to 40, but it doesnt make that much of a difference and is a lot of headache
#put the results into a dictionary
results={
    'inchikey':[],
    'dot_product':[],
    'exp_energy_parsed':[]
}
for i,temp_inchikey in enumerate(inchikeys):
    if i%500==0:
        print(i)
    temp_min_energy=temp.loc[
            (temp['InChIKey']==temp_inchikey) & 
            (temp.experimental_collision_parsed>35) & 
            (temp.experimental_collision_parsed<45)
        ].experimental_collision_parsed.min()
    #print(temp_min_energy)
    temp_index=temp.loc[
            (temp['InChIKey']==temp_inchikey) & 
            (temp.experimental_collision_parsed==temp_min_energy)
        ].index[0]

    results['inchikey'].append(temp.at[temp_index,'InChIKey'])
    results['dot_product'].append(temp.at[temp_index,'dot_product'])
    results['exp_energy_parsed'].append(temp.at[temp_index,'experimental_collision_parsed'])
    #print(results)
    #hold=input('hold')
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000

# %%
result_panda=pd.DataFrame.from_dict(results)

# %%
result_panda
# Out:
#                          inchikey  dot_product  exp_energy_parsed
# 0     FMYKJLXRRQTBOR-SQNIBIBYSA-N     0.784657               38.0
# 1     FAXGPCHRFPCXOO-DPQSSDLTSA-N     0.702553               41.0
# 2     MQKSCOKUMZMISB-GPWKTZPCSA-N     0.887830               37.0
# 3     KRTOMQDUKGRFDJ-ZAHDIIMDSA-N     0.962515               39.0
# 4     FTODBIPDTXRIGS-UHFFFAOYSA-N     0.647121               36.0
# ...                           ...          ...                ...
# 8300  INOIOAWTVPHTCJ-GHVJWSGMSA-N     0.999495               42.0
# 8301  HQFSCLFJTFOOGZ-GHVJWSGMSA-N     0.955231               37.0
# 8302  YFLCMJHFLLCCHN-NVQSTNCTSA-N     0.891397               39.0
# 8303  PKLSFJOTJYLMTM-CGAFSULGSA-N     0.989249               42.0
# 8304  UAKYQMHTPLVMJD-GJOJTGTQSA-N     0.988349               37.0
#
# [8305 rows x 3 columns]

# %%
result_panda.dot_product.hist()
# Out:
# <AxesSubplot:>

# %%
result_panda.to_pickle(output_address)
