# %%
import pandas as pd

# %%
from rdkit import Chem
from rdkit.Chem import Draw
import matplotlib.pyplot as plt

# %%
input_file_address='./input_2_edited_H.txt'

# %%
bit_panda=pd.read_csv(input_file_address,sep='\t')

# %%
bit_panda
# Out:
#    associated_with  bit_number             bit_description
# 0             good         185  at least 2 rings of size 6
# 1             good         333               C(~C)(~C)(~C)
# 2             good         345                  C(~C)(~N)
# 3             good         356               C(~C)(:C)(:C)
# 4             good         365                       C(~N)
# 5             good         430               C(-C)(-C)(=C)
# 6             good         516               [#1]-C=C-[#1]
# 7             good         540                  C-N-C-[#1]
# 8             good         688                   C-C:C-C-C
# 9             good         708                  C-C(C)-C-C
# 10            good         709                C-C(C)-C-C-C
# 11            good         710                C-C-C(C)-C-C
# 12             bad          19                     >= 2 O
# 13             bad         143   at least 1 ring of size 5
# 14             bad         340               C(~C)(~C)(~N)
# 15             bad         374                     Methyl
# 16             bad         376                   C(~N)(:C)
# 17             bad         449                   C(-N)(=C)
# 18             bad         545                     N-C:C-C
# 19             bad         600                   N-C:C:C-C
# 20             bad         665                   N-C:C-C-C

# %%
for index, series in bit_panda.iterrows():
    if index==0 or index==12 or index==13 or index==15:
        continue
    else:
        temp_mol=Chem.MolFromSmarts(series['bit_description'])
        #Draw.MolToImage(temp_mol)
        Draw.MolToFile(temp_mol,'./'+str(series['associated_with'])+'_'+str(series['bit_number'])+'.png',size=(100,100))

# %%
# temp="N-C:C-C"
# temp_mol=Chem.MolFromSmiles(temp)

# %%
#Draw.MolToImage(temp_mol)

# %%
# Draw.MolToFile(temp_mol,'./temp.png',size=(100,100))
